# %%
from pandas import read_csv
from scipy.cluster import hierarchy
from matplotlib import pyplot as plt

df = read_csv("data/einkaufsparadis.csv")

# %%
Z = hierarchy.linkage(df.select_dtypes("number"), method="ward")

# %%
plt.plot(df.select_dtypes("number"))
print()
plt.show()
# Out:
# (np.float64(-4.95), np.float64(103.95))
